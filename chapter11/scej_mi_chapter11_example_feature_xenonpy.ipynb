# %% [markdown]
# <a href="https://colab.research.google.com/github/mipypf/scej-mi/blob/develop/chapter11/scej_mi_chapter11_example_feature_xenonpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Google Colabの準備

# %% [markdown]
# #### 右上の「接続」をクリックし、ランタイムに接続

# %% [markdown]
# #### ライブラリをインストール

# %%
# !pip uninstall -y scikit-image nx-cugraph-cu12 networkx thinc spacy fastai # 競合するライブラリを削除
# !pip install pymatgen==2024.4.13 rdkit==2024.3.5 xenonpy==0.6.5
# Out:
# Found existing installation: scikit-image 0.25.2
# Uninstalling scikit-image-0.25.2:
#   Successfully uninstalled scikit-image-0.25.2
# Found existing installation: nx-cugraph-cu12 25.2.0
# Uninstalling nx-cugraph-cu12-25.2.0:
#   Successfully uninstalled nx-cugraph-cu12-25.2.0
# Found existing installation: networkx 3.4.2
# Uninstalling networkx-3.4.2:
#   Successfully uninstalled networkx-3.4.2
# Found existing installation: thinc 8.3.6
# Uninstalling thinc-8.3.6:
#   Successfully uninstalled thinc-8.3.6
# Found existing installation: spacy 3.8.6
# Uninstalling spacy-3.8.6:
#   Successfully uninstalled spacy-3.8.6
# Found existing installation: fastai 2.7.19
# Uninstalling fastai-2.7.19:
#   Successfully uninstalled fastai-2.7.19
# Collecting pymatgen==2024.4.13
#   Downloading pymatgen-2024.4.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Collecting rdkit==2024.3.5
#   Downloading rdkit-2024.3.5-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (3.9 kB)
# Collecting xenonpy==0.6.5
#   Downloading xenonpy-0.6.5-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: matplotlib>=1.5 in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (3.10.0)
# Collecting monty>=2024.2.2 (from pymatgen==2024.4.13)
#   Downloading monty-2025.3.3-py3-none-any.whl.metadata (3.6 kB)
# Collecting networkx>=2.2 (from pymatgen==2024.4.13)
#   Downloading networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Requirement already satisfied: numpy>=1.25.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (2.0.2)
# Collecting palettable>=3.1.1 (from pymatgen==2024.4.13)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (2.2.2)
# Requirement already satisfied: plotly>=4.5.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (5.24.1)
# Collecting pybtex (from pymatgen==2024.4.13)
#   Downloading pybtex-0.24.0-py2.py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (2.32.3)
# Collecting ruamel.yaml>=0.17.0 (from pymatgen==2024.4.13)
#   Downloading ruamel.yaml-0.18.12-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (1.15.3)
# Collecting spglib>=2.0.2 (from pymatgen==2024.4.13)
#   Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (1.13.1)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (0.9.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (4.67.1)
# Collecting uncertainties>=3.1.4 (from pymatgen==2024.4.13)
#   Downloading uncertainties-3.2.3-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: joblib in /usr/local/lib/python3.11/dist-packages (from pymatgen==2024.4.13) (1.5.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from rdkit==2024.3.5) (11.2.1)
# Requirement already satisfied: seaborn in /usr/local/lib/python3.11/dist-packages (from xenonpy==0.6.5) (0.13.2)
# Collecting mordred (from xenonpy==0.6.5)
#   Downloading mordred-1.2.0.tar.gz (128 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.8/128.8 kB 9.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting Deprecated (from xenonpy==0.6.5)
#   Downloading Deprecated-1.2.18-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: scikit-learn>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from xenonpy==0.6.5) (1.6.1)
# Requirement already satisfied: torch>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from xenonpy==0.6.5) (2.6.0+cu124)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5->pymatgen==2024.4.13) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5->pymatgen==2024.4.13) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5->pymatgen==2024.4.13) (4.58.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5->pymatgen==2024.4.13) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5->pymatgen==2024.4.13) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5->pymatgen==2024.4.13) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=1.5->pymatgen==2024.4.13) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->pymatgen==2024.4.13) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->pymatgen==2024.4.13) (2025.2)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly>=4.5.0->pymatgen==2024.4.13) (9.1.2)
# Collecting ruamel.yaml.clib>=0.2.7 (from ruamel.yaml>=0.17.0->pymatgen==2024.4.13)
#   Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (2.7 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.23.0->xenonpy==0.6.5) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.9.0 in /usr/local/lib/python3.11/dist-packages (from spglib>=2.0.2->pymatgen==2024.4.13) (4.13.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->xenonpy==0.6.5) (3.18.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->xenonpy==0.6.5) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->xenonpy==0.6.5) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->xenonpy==0.6.5) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->xenonpy==0.6.5) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->xenonpy==0.6.5) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch>=1.7.0->xenonpy==0.6.5)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.7.0->xenonpy==0.6.5) (3.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->pymatgen==2024.4.13) (1.3.0)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from Deprecated->xenonpy==0.6.5) (1.17.2)
# Requirement already satisfied: six==1.* in /usr/local/lib/python3.11/dist-packages (from mordred->xenonpy==0.6.5) (1.17.0)
# Collecting numpy>=1.25.0 (from pymatgen==2024.4.13)
#   Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 1.9 MB/s eta 0:00:00
# Collecting networkx>=2.2 (from pymatgen==2024.4.13)
#   Downloading networkx-2.8.8-py3-none-any.whl.metadata (5.1 kB)
# Requirement already satisfied: PyYAML>=3.01 in /usr/local/lib/python3.11/dist-packages (from pybtex->pymatgen==2024.4.13) (6.0.2)
# Collecting latexcodec>=1.0.4 (from pybtex->pymatgen==2024.4.13)
#   Downloading latexcodec-3.0.0-py3-none-any.whl.metadata (4.9 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2024.4.13) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2024.4.13) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2024.4.13) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->pymatgen==2024.4.13) (2025.4.26)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.7.0->xenonpy==0.6.5) (3.0.2)
# Downloading pymatgen-2024.4.13-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 68.5 MB/s eta 0:00:00
# Downloading rdkit-2024.3.5-cp311-cp311-manylinux_2_28_x86_64.whl (33.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 33.1/33.1 MB 24.5 MB/s eta 0:00:00
# Downloading xenonpy-0.6.5-py3-none-any.whl (138 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.1/138.1 kB 6.2 MB/s eta 0:00:00
# Downloading monty-2025.3.3-py3-none-any.whl (51 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 3.0 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 14.3 MB/s eta 0:00:00
# Downloading ruamel.yaml-0.18.12-py3-none-any.whl (118 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 118.4/118.4 kB 7.3 MB/s eta 0:00:00
# Downloading spglib-2.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (809 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 809.0/809.0 kB 34.8 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 53.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 34.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 31.6 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.0 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.8 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.3 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 85.6 MB/s eta 0:00:00
# Downloading uncertainties-3.2.3-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.1/60.1 kB 4.3 MB/s eta 0:00:00
# Downloading Deprecated-1.2.18-py2.py3-none-any.whl (10.0 kB)
# Downloading networkx-2.8.8-py3-none-any.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 69.3 MB/s eta 0:00:00
# Downloading numpy-1.26.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (18.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.3/18.3 MB 30.8 MB/s eta 0:00:00
# Downloading pybtex-0.24.0-py2.py3-none-any.whl (561 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 561.4/561.4 kB 36.2 MB/s eta 0:00:00
# Downloading latexcodec-3.0.0-py3-none-any.whl (18 kB)
# Downloading ruamel.yaml.clib-0.2.12-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (739 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 739.1/739.1 kB 40.8 MB/s eta 0:00:00
# Building wheels for collected packages: mordred
#   Building wheel for mordred (setup.py) ... done
#   Created wheel for mordred: filename=mordred-1.2.0-py3-none-any.whl size=176718 sha256=4235ba35feb9872c487fa066f72c27761d70b74d16e6d1db3b02da364fb7eb4a
#   Stored in directory: /root/.cache/pip/wheels/8b/30/0b/84e3f6775306e74cf5957ee4d16b10bf3927dcec44cc23d5f2
# Successfully built mordred
# Installing collected packages: uncertainties, ruamel.yaml.clib, palettable, nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, numpy, networkx, latexcodec, Deprecated, spglib, ruamel.yaml, rdkit, pybtex, nvidia-cusparse-cu12, nvidia-cudnn-cu12, mordred, nvidia-cusolver-cu12, monty, pymatgen, xenonpy
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed Deprecated-1.2.18 latexcodec-3.0.0 monty-2025.3.3 mordred-1.2.0 networkx-2.8.8 numpy-1.26.4 nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 palettable-3.3.3 pybtex-0.24.0 pymatgen-2024.4.13 rdkit-2024.3.5 ruamel.yaml-0.18.12 ruamel.yaml.clib-0.2.12 spglib-2.6.0 uncertainties-3.2.3 xenonpy-0.6.5

# %% [markdown]
# #### 「ランタイム」タブから「セッションを再起動する」を選択し、「はい」をクリック

# %% [markdown]
# ### 無機材料の特徴量化（Xenonpyを使用）

# %% [markdown]
# #### ①ライブラリの呼び出し

# %%
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm

tqdm.pandas()

from pymatgen.core import Composition

import warnings

warnings.filterwarnings("ignore")

from xenonpy.datatools import preset
from xenonpy.descriptor import Compositions

# %% [markdown]
# #### ②対象の組成式の定義

# %%
data = {'composition_formula': ['SrTiO3']}
df = pd.DataFrame(data)
df
# Out:
#   composition_formula
# 0              SrTiO3

# %% [markdown]
# #### ③comp_dictを作成

# %%
df["comp_dict"] = df["composition_formula"].apply(lambda x: Composition(x).fractional_composition.as_dict())
df
# Out:
#   composition_formula                         comp_dict
# 0              SrTiO3  {'Sr': 0.2, 'Ti': 0.2, 'O': 0.6}

# %% [markdown]
# #### ④元素情報の読み込み

# %%
preset.sync("elements_completed")
# Out:
# fetching dataset `elements_completed` from https://github.com/yoshida-lab/dataset/releases/download/v0.1.3/elements_completed.pd.xz.

# %% [markdown]
# #### ⑤comp_dictから元素とその比率由来の特徴量を作成

# %%
cal = Compositions()
descriptor = cal.transform(df["comp_dict"])
df = pd.concat([df, descriptor], axis=1)
df
# Out:
#   composition_formula                         comp_dict  ave:atomic_number  \
# 0              SrTiO3  {'Sr': 0.2, 'Ti': 0.2, 'O': 0.6}               16.8
#
#    ave:atomic_radius  ave:atomic_radius_rahm  ave:atomic_volume  \
# 0         160.120852                   209.8              17.26
#
#    ave:atomic_weight  ave:boiling_point  ave:bulk_modulus  ave:c6_gb  ...  \
# 0            36.6968           1097.514         82.159719     896.02  ...
#
#    min:num_s_valence  min:period  min:specific_heat  min:thermal_conductivity  \
# 0                2.0         2.0              0.301                   0.02658
#
#    min:vdw_radius  min:vdw_radius_alvarez  min:vdw_radius_mm3  \
# 0           152.0                   150.0               182.0
#
#    min:vdw_radius_uff  min:sound_velocity  min:Polarizability
# 0               317.5               317.5               0.802
#
# [1 rows x 292 columns]

# %% [markdown]
# ### 実行環境の確認及び保存

# %%
# !python3 -V
# Out:
# Python 3.11.12

# %%
# !pip freeze > requirements_feature_xenonpy.txt

# %%
from google.colab import files

files.download('requirements_feature_xenonpy.txt')
